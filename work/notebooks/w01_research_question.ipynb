# %% [markdown]
# <a href="https://colab.research.google.com/github/Assem-ElQersh/FlyRank-ML-Internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Assem-ElQersh/FlyRank-ML-Internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# **Lane 2: Refresh / Content Opportunity Scoring.**
#
# I chose this lane because it solves a tangible, high-value business problem: content teams have limited capacity. Instead of guessing what to update, a predictive queue maximizes ROI by pointing editors directly to the pages with the highest probability of recovery if refreshed. It's not just an analysis; it's a direct decision-support tool.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# **The Decision:** Which declining or underperforming pages should we review and update first?
#
# **The Actor:** Content editors and SEO managers.
#
# **The Action:** Review the page, update outdated information, improve intent match, or consolidate thin content.
#
# **The Cost of a Wrong Call:** Wasted editor hours on a page that was never going to recover, while missing out on traffic from a page that actually needed help.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# Let's look at the sheer volume of pages that are losing traffic. This proves why a manual review is impossible and why we need an automated scoring system.

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/Assem-ElQersh/FlyRank-ML-Internship/main/data/raw/content_refresh_anonymized.csv')

declining = len(df[df['trend_direction'] == 'down'])
print(f"Declining pages: {declining:,} out of {len(df):,} ({(declining/len(df))*100:.1f}%)")

meaningful_decline = len(df[(df['trend_direction'] == 'down') & (df['impressions_90d'] > 500)])
print(f"Declining pages with >500 impressions: {meaningful_decline:,}")

print("\nThis proves the scale of the problem: human editors cannot manually review thousands of declining pages. We need a ranked queue.")
# Out:
# Declining pages: 16,262 out of 30,000 (54.2%)
# Declining pages with >500 impressions: 9,956
#
# This proves the scale of the problem: human editors cannot manually review thousands of declining pages. We need a ranked queue.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# **What I can claim:** I can provide an *observed, directional* ranking that acts as *decision-support* for editors. I can say "these pages share characteristics with pages that usually benefit from a refresh."
#
# **What I can never claim:** I will never claim that I have "reverse-engineered Google's algorithm" or that a refresh is *guaranteed* to cause a recovery (since this is observational data, not a controlled causal experiment).

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
