# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Assem-ElQersh/FlyRank-ML-Internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# This is a **Scoring/Ranking** task built on top of a binary classification problem. We are not just trying to predict a binary yes/no outcome; our actual business goal is to score every page with a probability and rank them so editors can work top-down.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# The target is whether the page is actively losing traffic (e.g., predicting if `trend_direction == 'down'`). This is an **observed outcome** calculated from actual historical impression data. It is a pure, leak-free proxy for "needs a refresh" because it relies on reality rather than a subjective product-defined flag.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# The success metric is **Precision@50** (or Precision@K). Since the action is an editor manually reviewing pages, they have limited time and will only ever look at the top of the queue. We don't care about overall accuracy across 30,000 pages; we care that out of the top 50 pages we tell them to fix, almost all of them are genuinely declining.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# The unit of analysis is a single published page (`content_id`). Every row in the dataframe represents one page's historical performance and static features.

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/Assem-ElQersh/FlyRank-ML-Internship/main/data/raw/content_refresh_anonymized.csv'
df = pd.read_csv(url)

print("Unit of analysis: One row = One Page (content_id)")
df[['content_id', 'content_type', 'word_count', 'impressions_90d', 'trend_direction']].head(3)
# Out:
# Unit of analysis: One row = One Page (content_id)
#              content_id     content_type  word_count  impressions_90d  \
# 0  content_304f48230142  keyword article      3221.0             3803
# 1  content_a1fb4e703a9e  keyword article      2481.0            15320
# 2  content_9aa793d4d895  keyword article      3515.0            12581
#
#   trend_direction
# 0            down
# 1            down
# 2            down

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# A fixed rule (like *'if impressions dropped > 20% and age > 300 days'*) is incredibly brittle. It treats a highly seasonal product page the same as an evergreen blog post. ML can capture non-linear interactions between dozens of features (like content type, competition level, position tier, and age) that a human couldn't possibly write an if-statement for.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
